# %%
# !pip install tensorflow  opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in d:\anaconda\lib\site-packages (2.12.0)
# Requirement already satisfied: opencv-python in d:\anaconda\lib\site-packages (4.7.0.72)
# Requirement already satisfied: tensorflow-intel==2.12.0 in d:\anaconda\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.20.3)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.6.3)
# Requirement already satisfied: h5py>=2.9.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: flatbuffers>=2.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.3.3)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (22.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: jax>=0.3.15 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: keras<2.13,>=2.12.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.7 in d:\anaconda\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in d:\anaconda\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\anaconda\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.17.3)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in d:\anaconda\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\anaconda\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\anaconda\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)

# %%
# !pip install mediapipe
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mediapipe in d:\anaconda\lib\site-packages (0.9.3.0)
# Requirement already satisfied: protobuf<4,>=3.11 in d:\anaconda\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: flatbuffers>=2.0 in d:\anaconda\lib\site-packages (from mediapipe) (23.3.3)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from mediapipe) (1.23.5)
# Requirement already satisfied: attrs>=19.1.0 in d:\anaconda\lib\site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: absl-py in d:\anaconda\lib\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (from mediapipe) (3.7.0)
# Requirement already satisfied: opencv-contrib-python in d:\anaconda\lib\site-packages (from mediapipe) (4.7.0.72)
# Requirement already satisfied: sounddevice>=0.4.4 in d:\anaconda\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in d:\anaconda\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib->mediapipe) (22.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->mediapipe) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (3.7.0)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: numpy>=1.20 in d:\anaconda\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)

# %%
# !pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sklearn
#   Using cached sklearn-0.0.post4.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [8 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\USER\AppData\Local\Temp\pip-install-t_0hna5q\sklearn_51b90a22ddab42d9aa09d7d58a82b8e8\setup.py", line 10, in <module>
#       LONG_DESCRIPTION = f.read()
#     File "D:\anaconda\lib\encodings\cp1252.py", line 23, in decode
#       return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#   UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 7: character maps to <undefined>
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)

# %%
# %pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: opencv-python in d:\anaconda\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.19.3 in d:\anaconda\lib\site-packages (from opencv-python) (1.23.5)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # keypoints using mp holistic

# %% [markdown]
#  Holistic pipeline integrates separate models for pose, face and hand components, each of which are optimized for their particular domain. However, because of their different specializations, the input to one component is not well-suited for the others.

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw rig

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # extract keypoint values

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# 21

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() 
if (1==1):
    
    print(results.face_landmarks )
else:
    np.zeros(1404)
# Out:
# landmark {
#   x: 0.41132670640945435
#   y: 0.6479058265686035
#   z: -0.03571164980530739
# }
# landmark {
#   x: 0.4129159152507782
#   y: 0.6039326786994934
#   z: -0.044588569551706314
# }
# landmark {
#   x: 0.41164442896842957
#   y: 0.6232166290283203
#   z: -0.028639668598771095
# }
# landmark {
#   x: 0.40505728125572205
#   y: 0.5704001188278198
#   z: -0.025646431371569633
# }
# landmark {
#   x: 0.41310831904411316
#   y: 0.5913181304931641
#   z: -0.04501483961939812
# }
# landmark {
#   x: 0.4128257930278778
#   y: 0.5778706073760986
#   z: -0.038484275341033936
# }
# landmark {
#   x: 0.41175854206085205
#   y: 0.5490263104438782
#   z: -0.006728247739374638
# }
# landmark {
#   x: 0.34763801097869873
#   y: 0.5606622099876404
#   z: 0.021725572645664215
# }
# landmark {
#   x: 0.41173362731933594
#   y: 0.5224505066871643
#   z: 0.0053443568758666515
# }
# landmark {
#   x: 0.41213569045066833
#   y: 0.5057626366615295
#   z: 0.007846564054489136
# }
# landmark {
#   x: 0.4124106168746948
#   y: 0.45498818159103394
#   z: 0.03161948546767235
# }
# landmark {
#   x: 0.41116490960121155
#   y: 0.653844952583313
#   z: -0.035733822733163834
# }
# landmark {
#   x: 0.41083937883377075
#   y: 0.6595076322555542
#   z: -0.033782102167606354
# }
# landmark {
#   x: 0.4104822874069214
#   y: 0.6628088355064392
#   z: -0.03085806965827942
# }
# landmark {
#   x: 0.4104631245136261
#   y: 0.6643991470336914
#   z: -0.03230191767215729
# }
# landmark {
#   x: 0.4104670584201813
#   y: 0.6681448221206665
#   z: -0.03465253487229347
# }
# landmark {
#   x: 0.41036999225616455
#   y: 0.6739746928215027
#   z: -0.03785109519958496
# }
# landmark {
#   x: 0.41007477045059204
#   y: 0.681370735168457
#   z: -0.03861914947628975
# }
# landmark {
#   x: 0.40899017453193665
#   y: 0.6983758211135864
#   z: -0.033982910215854645
# }
# landmark {
#   x: 0.41248437762260437
#   y: 0.6122646331787109
#   z: -0.04171311482787132
# }
# landmark {
#   x: 0.40469837188720703
#   y: 0.6148065328598022
#   z: -0.03195923939347267
# }
# landmark {
#   x: 0.31394511461257935
#   y: 0.5242952704429626
#   z: 0.0725863128900528
# }
# landmark {
#   x: 0.3720286190509796
#   y: 0.5695192813873291
#   z: 0.012375937774777412
# }
# landmark {
#   x: 0.36325803399086
#   y: 0.5709519982337952
#   z: 0.012509608641266823
# }
# landmark {
#   x: 0.3550565242767334
#   y: 0.570113480091095
#   z: 0.014661054126918316
# }
# landmark {
#   x: 0.34413543343544006
#   y: 0.5652037262916565
#   z: 0.021915888413786888
# }
# landmark {
#   x: 0.37958139181137085
#   y: 0.56546950340271
#   z: 0.01456037163734436
# }
# landmark {
#   x: 0.36249876022338867
#   y: 0.5362856984138489
#   z: 0.013602941296994686
# }
# landmark {
#   x: 0.371081680059433
#   y: 0.5372874736785889
#   z: 0.014689676463603973
# }
# landmark {
#   x: 0.3539639115333557
#   y: 0.538182258605957
#   z: 0.01572565548121929
# }
# landmark {
#   x: 0.347900390625
#   y: 0.5432374477386475
#   z: 0.01841602846980095
# }
# landmark {
#   x: 0.3369777798652649
#   y: 0.5725641250610352
#   z: 0.02451399154961109
# }
# landmark {
#   x: 0.37478435039520264
#   y: 0.7258780002593994
#   z: -0.03156483918428421
# }
# landmark {
#   x: 0.3450295627117157
#   y: 0.5581143498420715
#   z: 0.02500164322555065
# }
# landmark {
#   x: 0.30993783473968506
#   y: 0.5761497616767883
#   z: 0.061601974070072174
# }
# landmark {
#   x: 0.3272295594215393
#   y: 0.565516471862793
#   z: 0.03465323895215988
# }
# landmark {
#   x: 0.36723792552948
#   y: 0.6102654933929443
#   z: -0.007725317496806383
# }
# landmark {
#   x: 0.400606244802475
#   y: 0.6467550992965698
#   z: -0.03478839248418808
# }
# landmark {
#   x: 0.4015181064605713
#   y: 0.6600732207298279
#   z: -0.03321828320622444
# }
# landmark {
#   x: 0.3890109062194824
#   y: 0.6536363363265991
#   z: -0.03156747296452522
# }
# landmark {
#   x: 0.38125506043434143
#   y: 0.6618455648422241
#   z: -0.027342066168785095
# }
# landmark {
#   x: 0.3931404650211334
#   y: 0.6630428433418274
#   z: -0.030727878212928772
# }
# landmark {
#   x: 0.38639408349990845
#   y: 0.666977047920227
#   z: -0.026425594463944435
# }
# landmark {
#   x: 0.369867742061615
#   y: 0.6854346990585327
#   z: -0.022096460685133934
# }
# landmark {
#   x: 0.40582385659217834
#   y: 0.6041183471679688
#   z: -0.04409126192331314
# }
# landmark {
#   x: 0.40486031770706177
#   y: 0.5922450423240662
#   z: -0.04437748342752457
# }
# landmark {
#   x: 0.333135187625885
#   y: 0.5278470516204834
#   z: 0.025122953578829765
# }
# landmark {
#   x: 0.38440608978271484
#   y: 0.5811976790428162
#   z: -0.00041903031524270773
# }
# landmark {
#   x: 0.3845283091068268
#   y: 0.6089434623718262
#   z: -0.025317607447504997
# }
# landmark {
#   x: 0.38378894329071045
#   y: 0.604040265083313
#   z: -0.02178075909614563
# }
# landmark {
#   x: 0.339921772480011
#   y: 0.6133360266685486
#   z: 0.0024057526607066393
# }
# landmark {
#   x: 0.4050379693508148
#   y: 0.5797890424728394
#   z: -0.03647329658269882
# }
# landmark {
#   x: 0.3544415831565857
#   y: 0.509722888469696
#   z: 0.014547465369105339
# }
# landmark {
#   x: 0.34206944704055786
#   y: 0.5159500241279602
#   z: 0.020025406032800674
# }
# landmark {
#   x: 0.32360512018203735
#   y: 0.4977261424064636
#   z: 0.06189863383769989
# }
# landmark {
#   x: 0.3928847908973694
#   y: 0.5196219682693481
#   z: 0.007302792277187109
# }
# landmark {
#   x: 0.37878188490867615
#   y: 0.541439414024353
#   z: 0.016823796555399895
# }
# landmark {
#   x: 0.3631414473056793
#   y: 0.675570011138916
#   z: -0.017459841445088387
# }
# landmark {
#   x: 0.31482914090156555
#   y: 0.6962238550186157
#   z: 0.052870843559503555
# }
# landmark {
#   x: 0.39106485247612
#   y: 0.615655779838562
#   z: -0.023335449397563934
# }
# landmark {
#   x: 0.39851462841033936
#   y: 0.6192935109138489
#   z: -0.024958550930023193
# }
# landmark {
#   x: 0.37340083718299866
#   y: 0.6739715337753296
#   z: -0.018042277544736862
# }
# landmark {
#   x: 0.3771185874938965
#   y: 0.6729649305343628
#   z: -0.019996944814920425
# }
# landmark {
#   x: 0.33664384484291077
#   y: 0.5084207057952881
#   z: 0.02590843290090561
# }
# landmark {
#   x: 0.3841758072376251
#   y: 0.6160376071929932
#   z: -0.022176183760166168
# }
# landmark {
#   x: 0.37104082107543945
#   y: 0.5101780295372009
#   z: 0.01019679382443428
# }
# landmark {
#   x: 0.3696340024471283
#   y: 0.49955785274505615
#   z: 0.010975106619298458
# }
# landmark {
#   x: 0.36154162883758545
#   y: 0.46201008558273315
#   z: 0.03763489052653313
# }
# landmark {
#   x: 0.3302006721496582
#   y: 0.5023841261863708
#   z: 0.041655510663986206
# }
# landmark {
#   x: 0.36645421385765076
#   y: 0.47939246892929077
#   z: 0.024300865828990936
# }
# landmark {
#   x: 0.32743313908576965
#   y: 0.5243585705757141
#   z: 0.033731114119291306
# }
# landmark {
#   x: 0.32080522179603577
#   y: 0.524648904800415
#   z: 0.052155185490846634
# }
# landmark {
#   x: 0.40092673897743225
#   y: 0.6540408730506897
#   z: -0.035036493092775345
# }
# landmark {
#   x: 0.39139631390571594
#   y: 0.6590554714202881
#   z: -0.03173460811376572
# }
# landmark {
#   x: 0.38400891423225403
#   y: 0.6644079089164734
#   z: -0.02775387465953827
# }
# landmark {
#   x: 0.3932846188545227
#   y: 0.6183202266693115
#   z: -0.02179497852921486
# }
# landmark {
#   x: 0.37547168135643005
#   y: 0.673494815826416
#   z: -0.018982376903295517
# }
# landmark {
#   x: 0.3793144226074219
#   y: 0.6728272438049316
#   z: -0.025260716676712036
# }
# landmark {
#   x: 0.3778083026409149
#   y: 0.6726999282836914
#   z: -0.02023531310260296
# }
# landmark {
#   x: 0.39610666036605835
#   y: 0.6079259514808655
#   z: -0.03290495276451111
# }
# landmark {
#   x: 0.3876492977142334
#   y: 0.6671388149261475
#   z: -0.025344325229525566
# }
# landmark {
#   x: 0.3945264518260956
#   y: 0.6644328236579895
#   z: -0.028077103197574615
# }
# landmark {
#   x: 0.4022979140281677
#   y: 0.6631402373313904
#   z: -0.030431874096393585
# }
# landmark {
#   x: 0.398044615983963
#   y: 0.6984803676605225
#   z: -0.03428797796368599
# }
# landmark {
#   x: 0.39998558163642883
#   y: 0.6811907291412354
#   z: -0.03849956393241882
# }
# landmark {
#   x: 0.40076330304145813
#   y: 0.6733542084693909
#   z: -0.03766311705112457
# }
# landmark {
#   x: 0.4013890326023102
#   y: 0.6676608324050903
#   z: -0.03423737734556198
# }
# landmark {
#   x: 0.40193086862564087
#   y: 0.6646971106529236
#   z: -0.0318685881793499
# }
# landmark {
#   x: 0.38702628016471863
#   y: 0.6684362292289734
#   z: -0.02660665102303028
# }
# landmark {
#   x: 0.3859778642654419
#   y: 0.6694087982177734
#   z: -0.02885475941002369
# }
# landmark {
#   x: 0.38426634669303894
#   y: 0.6724643111228943
#   z: -0.031538281589746475
# }
# landmark {
#   x: 0.382444828748703
#   y: 0.6771751642227173
#   z: -0.031132102012634277
# }
# landmark {
#   x: 0.3740439713001251
#   y: 0.6505778431892395
#   z: -0.022264113649725914
# }
# landmark {
#   x: 0.3066764175891876
#   y: 0.638704776763916
#   z: 0.08087772130966187
# }
# landmark {
#   x: 0.41206228733062744
#   y: 0.6172977089881897
#   z: -0.03276517987251282
# }
# landmark {
#   x: 0.38264375925064087
#   y: 0.6708982586860657
#   z: -0.023119546473026276
# }
# landmark {
#   x: 0.38128119707107544
#   y: 0.6710668206214905
#   z: -0.024644773453474045
# }
# landmark {
#   x: 0.40111932158470154
#   y: 0.6244844198226929
#   z: -0.02725628763437271
# }
# landmark {
#   x: 0.3871026933193207
#   y: 0.6245015263557434
#   z: -0.0180373452603817
# }
# landmark {
#   x: 0.3999209702014923
#   y: 0.6219838857650757
#   z: -0.025950588285923004
# }
# landmark {
#   x: 0.3748621344566345
#   y: 0.5893716812133789
#   z: 3.620111237978563e-05
# }
# landmark {
#   x: 0.36065948009490967
#   y: 0.5975847840309143
#   z: 0.000457781832665205
# }
# landmark {
#   x: 0.38223353028297424
#   y: 0.6108358502388
#   z: -0.01848337985575199
# }
# landmark {
#   x: 0.33869749307632446
#   y: 0.4764297604560852
#   z: 0.048915598541498184
# }
# landmark {
#   x: 0.3446075916290283
#   y: 0.4866030216217041
#   z: 0.03239722549915314
# }
# landmark {
#   x: 0.35111770033836365
#   y: 0.4999166429042816
#   z: 0.01841946691274643
# }
# landmark {
#   x: 0.3771202564239502
#   y: 0.6908196210861206
#   z: -0.0277861375361681
# }
# landmark {
#   x: 0.39054957032203674
#   y: 0.502466082572937
#   z: 0.0076382337138056755
# }
# landmark {
#   x: 0.38828104734420776
#   y: 0.47865360975265503
#   z: 0.01969284750521183
# }
# landmark {
#   x: 0.3853101134300232
#   y: 0.45587289333343506
#   z: 0.0315062440931797
# }
# landmark {
#   x: 0.3480038046836853
#   y: 0.5687777996063232
#   z: 0.01829921081662178
# }
# landmark {
#   x: 0.3276124894618988
#   y: 0.5814599394798279
#   z: 0.026960546150803566
# }
# landmark {
#   x: 0.38440972566604614
#   y: 0.5614370703697205
#   z: 0.01644073612987995
# }
# landmark {
#   x: 0.33724910020828247
#   y: 0.5477758646011353
#   z: 0.02574671432375908
# }
# landmark {
#   x: 0.39092594385147095
#   y: 0.5721299648284912
#   z: -0.0014040673850104213
# }
# landmark {
#   x: 0.3903678059577942
#   y: 0.6015293598175049
#   z: -0.031741779297590256
# }
# landmark {
#   x: 0.31788188219070435
#   y: 0.592365562915802
#   z: 0.03321155905723572
# }
# landmark {
#   x: 0.3336571455001831
#   y: 0.587598979473114
#   z: 0.017395803704857826
# }
# landmark {
#   x: 0.34506163001060486
#   y: 0.5895842909812927
#   z: 0.009275181218981743
# }
# landmark {
#   x: 0.36161988973617554
#   y: 0.5870122909545898
#   z: 0.006815652828663588
# }
# landmark {
#   x: 0.3739553391933441
#   y: 0.5817995071411133
#   z: 0.00647385697811842
# }
# landmark {
#   x: 0.38362839818000793
#   y: 0.575089693069458
#   z: 0.006197590380907059
# }
# landmark {
#   x: 0.4033448398113251
#   y: 0.552934467792511
#   z: -0.004674925003200769
# }
# landmark {
#   x: 0.31882625818252563
#   y: 0.6166946291923523
#   z: 0.02474292740225792
# }
# landmark {
#   x: 0.3297373950481415
#   y: 0.5460749864578247
#   z: 0.03034115955233574
# }
# landmark {
#   x: 0.4084109961986542
#   y: 0.6119265556335449
#   z: -0.0415535606443882
# }
# landmark {
#   x: 0.3855937123298645
#   y: 0.5904008150100708
#   z: -0.00703459931537509
# }
# landmark {
#   x: 0.30579081177711487
#   y: 0.5830485820770264
#   z: 0.08936230093240738
# }
# landmark {
#   x: 0.39076659083366394
#   y: 0.5672580003738403
#   z: 0.007078263908624649
# }
# landmark {
#   x: 0.3812282979488373
#   y: 0.6137576699256897
#   z: -0.010822853073477745
# }
# landmark {
#   x: 0.3417400121688843
#   y: 0.5585324764251709
#   z: 0.026404498144984245
# }
# landmark {
#   x: 0.3897305428981781
#   y: 0.5958133935928345
#   z: -0.02714473195374012
# }
# landmark {
#   x: 0.3090609610080719
#   y: 0.667519211769104
#   z: 0.06931644678115845
# }
# landmark {
#   x: 0.384552001953125
#   y: 0.5576605796813965
#   z: 0.019516266882419586
# }
# landmark {
#   x: 0.3973522484302521
#   y: 0.5862472057342529
#   z: -0.03309989720582962
# }
# landmark {
#   x: 0.3348139226436615
#   y: 0.7108625769615173
#   z: 0.0034559392370283604
# }
# landmark {
#   x: 0.3338671326637268
#   y: 0.7303706407546997
#   z: 0.01466538105159998
# }
# landmark {
#   x: 0.30907946825027466
#   y: 0.6278509497642517
#   z: 0.052533090114593506
# }
# landmark {
#   x: 0.32394975423812866
#   y: 0.6979959607124329
#   z: 0.017406219616532326
# }
# landmark {
#   x: 0.3152899742126465
#   y: 0.5492790341377258
#   z: 0.05970282107591629
# }
# landmark {
#   x: 0.3717447519302368
#   y: 0.7411884069442749
#   z: -0.030273107811808586
# }
# landmark {
#   x: 0.4089752435684204
#   y: 0.6169953346252441
#   z: -0.032329753041267395
# }
# landmark {
#   x: 0.3777460753917694
#   y: 0.6006107926368713
#   z: -0.0066315000876784325
# }
# landmark {
#   x: 0.3194020390510559
#   y: 0.5699512362480164
#   z: 0.04214403033256531
# }
# landmark {
#   x: 0.3557880222797394
#   y: 0.5637948513031006
#   z: 0.01640518195927143
# }
# landmark {
#   x: 0.36330005526542664
#   y: 0.5647086501121521
#   z: 0.01456813421100378
# }
# landmark {
#   x: 0.3770579397678375
#   y: 0.6758854389190674
#   z: -0.024367505684494972
# }
# landmark {
#   x: 0.31963056325912476
#   y: 0.6416547298431396
#   z: 0.02052544616162777
# }
# landmark {
#   x: 0.387376070022583
#   y: 0.7595347166061401
#   z: -0.03135198354721069
# }
# landmark {
#   x: 0.3595651686191559
#   y: 0.7493235468864441
#   z: -0.012036250904202461
# }
# landmark {
#   x: 0.3474780023097992
#   y: 0.7420275807380676
#   z: -0.00042647821828722954
# }
# landmark {
#   x: 0.4123949706554413
#   y: 0.47974449396133423
#   z: 0.019207928329706192
# }
# landmark {
#   x: 0.4061897397041321
#   y: 0.7610377073287964
#   z: -0.033309418708086014
# }
# landmark {
#   x: 0.3706763982772827
#   y: 0.5636430382728577
#   z: 0.014886242337524891
# }
# landmark {
#   x: 0.37750598788261414
#   y: 0.5612152218818665
#   z: 0.016732681542634964
# }
# landmark {
#   x: 0.38194847106933594
#   y: 0.559340238571167
#   z: 0.019174393266439438
# }
# landmark {
#   x: 0.3231129050254822
#   y: 0.5458259582519531
#   z: 0.03915835916996002
# }
# landmark {
#   x: 0.37745392322540283
#   y: 0.5516320466995239
#   z: 0.017056768760085106
# }
# landmark {
#   x: 0.37015658617019653
#   y: 0.5501056909561157
#   z: 0.015756215900182724
# }
# landmark {
#   x: 0.36353325843811035
#   y: 0.5496529340744019
#   z: 0.015793010592460632
# }
# landmark {
#   x: 0.35637331008911133
#   y: 0.551249623298645
#   z: 0.01725773885846138
# }
# landmark {
#   x: 0.35126179456710815
#   y: 0.5538504123687744
#   z: 0.019282864406704903
# }
# landmark {
#   x: 0.3085328936576843
#   y: 0.5510983467102051
#   z: 0.08369719982147217
# }
# landmark {
#   x: 0.35088610649108887
#   y: 0.5621917247772217
#   z: 0.01920633763074875
# }
# landmark {
#   x: 0.4114227890968323
#   y: 0.6316096782684326
#   z: -0.029152939096093178
# }
# landmark {
#   x: 0.38254863023757935
#   y: 0.6415714621543884
#   z: -0.02395770512521267
# }
# landmark {
#   x: 0.3909527063369751
#   y: 0.6126593351364136
#   z: -0.025165995582938194
# }
# landmark {
#   x: 0.3996831476688385
#   y: 0.6336590051651001
#   z: -0.029555290937423706
# }
# landmark {
#   x: 0.41147875785827637
#   y: 0.5373427271842957
#   z: 0.0024033437948673964
# }
# landmark {
#   x: 0.34677284955978394
#   y: 0.7237496972084045
#   z: -0.008356302045285702
# }
# landmark {
#   x: 0.35869669914245605
#   y: 0.7328827977180481
#   z: -0.019288593903183937
# }
# landmark {
#   x: 0.3879042863845825
#   y: 0.7465618848800659
#   z: -0.03932127356529236
# }
# landmark {
#   x: 0.323522686958313
#   y: 0.7169134020805359
#   z: 0.033904146403074265
# }
# landmark {
#   x: 0.3824997544288635
#   y: 0.5548222064971924
#   z: 0.01872902177274227
# }
# landmark {
#   x: 0.3976476788520813
#   y: 0.5700779557228088
#   z: -0.012516586109995842
# }
# landmark {
#   x: 0.4071934223175049
#   y: 0.7478867769241333
#   z: -0.040856022387742996
# }
# landmark {
#   x: 0.3725650906562805
#   y: 0.7551005482673645
#   z: -0.023753389716148376
# }
# landmark {
#   x: 0.31118667125701904
#   y: 0.6547932028770447
#   z: 0.044203344732522964
# }
# landmark {
#   x: 0.39387497305870056
#   y: 0.6658436059951782
#   z: -0.029504232108592987
# }
# landmark {
#   x: 0.39281541109085083
#   y: 0.6680671572685242
#   z: -0.032011959701776505
# }
# landmark {
#   x: 0.3916199803352356
#   y: 0.6725422143936157
#   z: -0.03511862829327583
# }
# landmark {
#   x: 0.3904041349887848
#   y: 0.6795095205307007
#   z: -0.03558571636676788
# }
# landmark {
#   x: 0.38650256395339966
#   y: 0.6953011155128479
#   z: -0.032382577657699585
# }
# landmark {
#   x: 0.3807089626789093
#   y: 0.6709019541740417
#   z: -0.022664053365588188
# }
# landmark {
#   x: 0.37825852632522583
#   y: 0.6699734926223755
#   z: -0.022711388766765594
# }
# landmark {
#   x: 0.37568673491477966
#   y: 0.6685274839401245
#   z: -0.022392671555280685
# }
# landmark {
#   x: 0.36699044704437256
#   y: 0.6622570753097534
#   z: -0.01936151273548603
# }
# landmark {
#   x: 0.3319604992866516
#   y: 0.6423929929733276
#   z: 0.003551514819264412
# }
# landmark {
#   x: 0.3973197340965271
#   y: 0.5616888999938965
#   z: -0.0023210770450532436
# }
# landmark {
#   x: 0.3919348418712616
#   y: 0.5452104806900024
#   z: 0.01607390120625496
# }
# landmark {
#   x: 0.38646799325942993
#   y: 0.549561619758606
#   z: 0.018522905185818672
# }
# landmark {
#   x: 0.38219380378723145
#   y: 0.6698514819145203
#   z: -0.022148221731185913
# }
# landmark {
#   x: 0.32947197556495667
#   y: 0.6751681566238403
#   z: 0.0073329186998307705
# }
# landmark {
#   x: 0.4000318944454193
#   y: 0.5408952236175537
#   z: 0.006435921881347895
# }
# landmark {
#   x: 0.38027822971343994
#   y: 0.7110378742218018
#   z: -0.03152542933821678
# }
# landmark {
#   x: 0.4124424457550049
#   y: 0.5679359436035156
#   z: -0.027624307200312614
# }
# landmark {
#   x: 0.40406447649002075
#   y: 0.5620088577270508
#   z: -0.015604785643517971
# }
# landmark {
#   x: 0.41207942366600037
#   y: 0.5587793588638306
#   z: -0.016653986647725105
# }
# landmark {
#   x: 0.3915599584579468
#   y: 0.588422417640686
#   z: -0.017254291102290154
# }
# landmark {
#   x: 0.4078957140445709
#   y: 0.7320035099983215
#   z: -0.041987061500549316
# }
# landmark {
#   x: 0.40849989652633667
#   y: 0.7141779661178589
#   z: -0.03828407824039459
# }
# landmark {
#   x: 0.394186407327652
#   y: 0.7144607305526733
#   z: -0.0372360534965992
# }
# landmark {
#   x: 0.3600890040397644
#   y: 0.6936410665512085
#   z: -0.018970893695950508
# }
# landmark {
#   x: 0.37389621138572693
#   y: 0.6246740818023682
#   z: -0.011386425234377384
# }
# landmark {
#   x: 0.3692070245742798
#   y: 0.704444169998169
#   z: -0.02564672753214836
# }
# landmark {
#   x: 0.3526900112628937
#   y: 0.6253505349159241
#   z: -0.008685097098350525
# }
# landmark {
#   x: 0.36496075987815857
#   y: 0.6374145150184631
#   z: -0.013867813162505627
# }
# landmark {
#   x: 0.3440517783164978
#   y: 0.647583544254303
#   z: -0.00781354121863842
# }
# landmark {
#   x: 0.39028486609458923
#   y: 0.7313042283058167
#   z: -0.04031219705939293
# }
# landmark {
#   x: 0.3860221803188324
#   y: 0.5973724126815796
#   z: -0.013835547491908073
# }
# landmark {
#   x: 0.35107770562171936
#   y: 0.7061581611633301
#   z: -0.013998650945723057
# }
# landmark {
#   x: 0.3628356456756592
#   y: 0.7171847820281982
#   z: -0.022662503644824028
# }
# landmark {
#   x: 0.35317012667655945
#   y: 0.679455041885376
#   z: -0.014139692299067974
# }
# landmark {
#   x: 0.32110387086868286
#   y: 0.6632866263389587
#   z: 0.017892036586999893
# }
# landmark {
#   x: 0.3408004641532898
#   y: 0.6848787665367126
#   z: -0.006461193785071373
# }
# landmark {
#   x: 0.31521397829055786
#   y: 0.6786569356918335
#   z: 0.03370124474167824
# }
# landmark {
#   x: 0.3571241497993469
#   y: 0.6553850769996643
#   z: -0.01414657011628151
# }
# landmark {
#   x: 0.39175698161125183
#   y: 0.5801294445991516
#   z: -0.009456800296902657
# }
# landmark {
#   x: 0.39332491159439087
#   y: 0.6058688163757324
#   z: -0.03397533670067787
# }
# landmark {
#   x: 0.3872411847114563
#   y: 0.6121183037757874
#   z: -0.02685682103037834
# }
# landmark {
#   x: 0.39738479256629944
#   y: 0.5959158539772034
#   z: -0.03809359297156334
# }
# landmark {
#   x: 0.385041207075119
#   y: 0.5341072678565979
#   z: 0.015120099298655987
# }
# landmark {
#   x: 0.37134188413619995
#   y: 0.5267913341522217
#   z: 0.014342370443046093
# }
# landmark {
#   x: 0.35954856872558594
#   y: 0.5253331661224365
#   z: 0.014218364842236042
# }
# landmark {
#   x: 0.34927141666412354
#   y: 0.5282189249992371
#   z: 0.01668199524283409
# }
# landmark {
#   x: 0.34159377217292786
#   y: 0.535585343837738
#   z: 0.020831821486353874
# }
# landmark {
#   x: 0.33537301421165466
#   y: 0.5615139007568359
#   z: 0.0294384453445673
# }
# landmark {
#   x: 0.3082774579524994
#   y: 0.6018216013908386
#   z: 0.05733638256788254
# }
# landmark {
#   x: 0.34166136384010315
#   y: 0.576654851436615
#   z: 0.019223395735025406
# }
# landmark {
#   x: 0.35052862763404846
#   y: 0.5785405039787292
#   z: 0.014158902689814568
# }
# landmark {
#   x: 0.36196354031562805
#   y: 0.5783457159996033
#   z: 0.011025913991034031
# }
# landmark {
#   x: 0.37309029698371887
#   y: 0.5753036141395569
#   z: 0.010172301903367043
# }
# landmark {
#   x: 0.38206613063812256
#   y: 0.5703178644180298
#   z: 0.011775646358728409
# }
# landmark {
#   x: 0.38822710514068604
#   y: 0.5651484727859497
#   z: 0.01214894000440836
# }
# landmark {
#   x: 0.30602753162384033
#   y: 0.6114864349365234
#   z: 0.0881567969918251
# }
# landmark {
#   x: 0.38746291399002075
#   y: 0.6167324781417847
#   z: -0.023436134681105614
# }
# landmark {
#   x: 0.39806869626045227
#   y: 0.5778657793998718
#   z: -0.021651478484272957
# }
# landmark {
#   x: 0.39988836646080017
#   y: 0.6038142442703247
#   z: -0.04011400043964386
# }
# landmark {
#   x: 0.40446722507476807
#   y: 0.6113955974578857
#   z: -0.038197148591279984
# }
# landmark {
#   x: 0.3997431695461273
#   y: 0.607216477394104
#   z: -0.036684904247522354
# }
# landmark {
#   x: 0.38995739817619324
#   y: 0.6212479472160339
#   z: -0.021537218242883682
# }
# landmark {
#   x: 0.4059131443500519
#   y: 0.6116853952407837
#   z: -0.04049619287252426
# }
# landmark {
#   x: 0.406418114900589
#   y: 0.6164560317993164
#   z: -0.03214053809642792
# }
# landmark {
#   x: 0.38786694407463074
#   y: 0.5569735765457153
#   z: 0.01843853108584881
# }
# landmark {
#   x: 0.39307257533073425
#   y: 0.5575792789459229
#   z: 0.013279492035508156
# }
# landmark {
#   x: 0.39616450667381287
#   y: 0.5569882988929749
#   z: 0.007378430105745792
# }
# landmark {
#   x: 0.34793123602867126
#   y: 0.5559949278831482
#   z: 0.021752994507551193
# }
# landmark {
#   x: 0.3427446484565735
#   y: 0.5495556592941284
#   z: 0.022526374086737633
# }
# landmark {
#   x: 0.4194023609161377
#   y: 0.5708094239234924
#   z: -0.02459556609392166
# }
# landmark {
#   x: 0.4701034128665924
#   y: 0.5643812417984009
#   z: 0.02929845079779625
# }
# landmark {
#   x: 0.4190373420715332
#   y: 0.6149653196334839
#   z: -0.031088829040527344
# }
# landmark {
#   x: 0.49873995780944824
#   y: 0.5306096076965332
#   z: 0.0845259353518486
# }
# landmark {
#   x: 0.4466298520565033
#   y: 0.5717132091522217
#   z: 0.017186211422085762
# }
# landmark {
#   x: 0.45513203740119934
#   y: 0.5735694766044617
#   z: 0.018309740349650383
# }
# landmark {
#   x: 0.46295517683029175
#   y: 0.5731785297393799
#   z: 0.021332480013370514
# }
# landmark {
#   x: 0.4729311466217041
#   y: 0.5691642761230469
#   z: 0.029885437339544296
# }
# landmark {
#   x: 0.4394645392894745
#   y: 0.5673277974128723
#   z: 0.018247200176119804
# }
# landmark {
#   x: 0.45741331577301025
#   y: 0.5400123596191406
#   z: 0.019698696210980415
# }
# landmark {
#   x: 0.4490833878517151
#   y: 0.540347695350647
#   z: 0.01944773457944393
# }
# landmark {
#   x: 0.4653875231742859
#   y: 0.5424833297729492
#   z: 0.022804411128163338
# }
# landmark {
#   x: 0.47078555822372437
#   y: 0.5478231310844421
#   z: 0.026016883552074432
# }
# landmark {
#   x: 0.47930076718330383
#   y: 0.5766987204551697
#   z: 0.03303248807787895
# }
# landmark {
#   x: 0.43947553634643555
#   y: 0.7265912890434265
#   z: -0.02812899462878704
# }
# landmark {
#   x: 0.47244033217430115
#   y: 0.5621650815010071
#   z: 0.03297904133796692
# }
# landmark {
#   x: 0.5010579228401184
#   y: 0.5819552540779114
#   z: 0.07369181513786316
# }
# landmark {
#   x: 0.48799893260002136
#   y: 0.5705121755599976
#   z: 0.04434596747159958
# }
# landmark {
#   x: 0.4519968628883362
#   y: 0.6119472980499268
#   z: -0.0029506138525903225
# }
# landmark {
#   x: 0.4217650294303894
#   y: 0.6467834115028381
#   z: -0.03347063437104225
# }
# landmark {
#   x: 0.4196610152721405
#   y: 0.660147488117218
#   z: -0.03207946568727493
# }
# landmark {
#   x: 0.4322411119937897
#   y: 0.653523325920105
#   z: -0.02890532650053501
# }
# landmark {
#   x: 0.43861472606658936
#   y: 0.6617355346679688
#   z: -0.02370123751461506
# }
# landmark {
#   x: 0.4272797703742981
#   y: 0.6629845499992371
#   z: -0.02850421704351902
# }
# landmark {
#   x: 0.43309590220451355
#   y: 0.6668813228607178
#   z: -0.02340508997440338
# }
# landmark {
#   x: 0.44694989919662476
#   y: 0.685778796672821
#   z: -0.01747974194586277
# }
# landmark {
#   x: 0.4197201728820801
#   y: 0.604398250579834
#   z: -0.043432749807834625
# }
# landmark {
#   x: 0.42086106538772583
#   y: 0.592622697353363
#   z: -0.043551795184612274
# }
# landmark {
#   x: 0.48508840799331665
#   y: 0.5337206125259399
#   z: 0.03430093824863434
# }
# landmark {
#   x: 0.4357830584049225
#   y: 0.5825130939483643
#   z: 0.0027509466744959354
# }
# landmark {
#   x: 0.4377954304218292
#   y: 0.6096581816673279
#   z: -0.022158632054924965
# }
# landmark {
#   x: 0.43808531761169434
#   y: 0.60478276014328
#   z: -0.018524043262004852
# }
# landmark {
#   x: 0.4768249988555908
#   y: 0.6163846254348755
#   z: 0.010255285538733006
# }
# landmark {
#   x: 0.4202476143836975
#   y: 0.5801624655723572
#   z: -0.03542996197938919
# }
# landmark {
#   x: 0.4669744670391083
#   y: 0.514838457107544
#   z: 0.020645804703235626
# }
# landmark {
#   x: 0.47789713740348816
#   y: 0.5216822624206543
#   z: 0.027692949399352074
# }
# landmark {
#   x: 0.4923709034919739
#   y: 0.5038314461708069
#   z: 0.07251230627298355
# }
# landmark {
#   x: 0.4301452338695526
#   y: 0.5214956998825073
#   z: 0.009232824668288231
# }
# landmark {
#   x: 0.44131579995155334
#   y: 0.543844997882843
#   z: 0.02080199494957924
# }
# landmark {
#   x: 0.45371881127357483
#   y: 0.6760589480400085
#   z: -0.011903676204383373
# }
# landmark {
#   x: 0.48878392577171326
#   y: 0.6997274160385132
#   z: 0.06407835334539413
# }
# landmark {
#   x: 0.4312659800052643
#   y: 0.6160391569137573
#   z: -0.021098440513014793
# }
# landmark {
#   x: 0.42408037185668945
#   y: 0.6195090413093567
#   z: -0.023813026025891304
# }
# landmark {
#   x: 0.44452258944511414
#   y: 0.6738471388816833
#   z: -0.013180836103856564
# }
# landmark {
#   x: 0.4408033788204193
#   y: 0.6728457808494568
#   z: -0.015698768198490143
# }
# landmark {
#   x: 0.48284387588500977
#   y: 0.5146070122718811
#   z: 0.03430784121155739
# }
# landmark {
#   x: 0.4374311864376068
#   y: 0.6165462136268616
#   z: -0.019117893651127815
# }
# landmark {
#   x: 0.45156383514404297
#   y: 0.5138587355613708
#   z: 0.014293858781456947
# }
# landmark {
#   x: 0.4534573554992676
#   y: 0.5033590793609619
#   z: 0.015409229323267937
# }
# landmark {
#   x: 0.4608677625656128
#   y: 0.46577635407447815
#   z: 0.043696846812963486
# }
# landmark {
#   x: 0.4878159165382385
#   y: 0.5084141492843628
#   z: 0.050985582172870636
# }
# landmark {
#   x: 0.4565793573856354
#   y: 0.4831349849700928
#   z: 0.0295612420886755
# }
# landmark {
#   x: 0.48989638686180115
#   y: 0.5305461883544922
#   z: 0.04350170120596886
# }
# landmark {
#   x: 0.4944123923778534
#   y: 0.5309001207351685
#   z: 0.06294336169958115
# }
# landmark {
#   x: 0.4209345579147339
#   y: 0.6541459560394287
#   z: -0.033773407340049744
# }
# landmark {
#   x: 0.42953115701675415
#   y: 0.6589267253875732
#   z: -0.02927119843661785
# }
# landmark {
#   x: 0.4358174204826355
#   y: 0.6642884016036987
#   z: -0.024446656927466393
# }
# landmark {
#   x: 0.42887789011001587
#   y: 0.6185992360115051
#   z: -0.019917963072657585
# }
# landmark {
#   x: 0.4425213932991028
#   y: 0.6733168363571167
#   z: -0.014570305123925209
# }
# landmark {
#   x: 0.43906906247138977
#   y: 0.6728410720825195
#   z: -0.021343985572457314
# }
# landmark {
#   x: 0.4399328827857971
#   y: 0.6725985407829285
#   z: -0.01599743403494358
# }
# landmark {
#   x: 0.4276728332042694
#   y: 0.6084163784980774
#   z: -0.030777553096413612
# }
# landmark {
#   x: 0.431363046169281
#   y: 0.6670519113540649
#   z: -0.022499818354845047
# }
# landmark {
#   x: 0.42529356479644775
#   y: 0.664504885673523
#   z: -0.0260612815618515
# }
# landmark {
#   x: 0.41822391748428345
#   y: 0.6631788015365601
#   z: -0.029292890802025795
# }
# landmark {
#   x: 0.4195944666862488
#   y: 0.6986532211303711
#   z: -0.033091768622398376
# }
# landmark {
#   x: 0.41979607939720154
#   y: 0.6813705563545227
#   z: -0.03728686645627022
# }
# landmark {
#   x: 0.41963642835617065
#   y: 0.6735671162605286
#   z: -0.03638201206922531
# }
# landmark {
#   x: 0.41919153928756714
#   y: 0.667879581451416
#   z: -0.03293805941939354
# }
# landmark {
#   x: 0.41846197843551636
#   y: 0.6648244857788086
#   z: -0.030593818053603172
# }
# landmark {
#   x: 0.4318881034851074
#   y: 0.6685048937797546
#   z: -0.02361638844013214
# }
# landmark {
#   x: 0.4330142140388489
#   y: 0.6695404648780823
#   z: -0.02591349184513092
# }
# landmark {
#   x: 0.43464580178260803
#   y: 0.6726245284080505
#   z: -0.028433004394173622
# }
# landmark {
#   x: 0.4361906051635742
#   y: 0.6773848533630371
#   z: -0.027783093973994255
# }
# landmark {
#   x: 0.44535312056541443
#   y: 0.651117205619812
#   z: -0.017983896657824516
# }
# landmark {
#   x: 0.4980353116989136
#   y: 0.6437211036682129
#   z: 0.09323334693908691
# }
# landmark {
#   x: 0.43559664487838745
#   y: 0.6709370017051697
#   z: -0.019398638978600502
# }
# landmark {
#   x: 0.4371268153190613
#   y: 0.6711004972457886
#   z: -0.020898625254631042
# }
# landmark {
#   x: 0.42154523730278015
#   y: 0.6245774030685425
#   z: -0.02611536905169487
# }
# landmark {
#   x: 0.43401452898979187
#   y: 0.6247681379318237
#   z: -0.01566465012729168
# }
# landmark {
#   x: 0.422712504863739
#   y: 0.6221326589584351
#   z: -0.024907471612095833
# }
# landmark {
#   x: 0.4446181654930115
#   y: 0.5910140872001648
#   z: 0.004200631752610207
# }
# landmark {
#   x: 0.45806488394737244
#   y: 0.5998778939247131
#   z: 0.00593868363648653
# }
# landmark {
#   x: 0.43896257877349854
#   y: 0.6114997267723083
#   z: -0.01525181159377098
# }
# landmark {
#   x: 0.48056185245513916
#   y: 0.4817548096179962
#   z: 0.057569727301597595
# }
# landmark {
#   x: 0.47602301836013794
#   y: 0.49198397994041443
#   z: 0.03988444805145264
# }
# landmark {
#   x: 0.4704153537750244
#   y: 0.5052443742752075
#   z: 0.024999422952532768
# }
# landmark {
#   x: 0.43978363275527954
#   y: 0.691247284412384
#   z: -0.023893173784017563
# }
# landmark {
#   x: 0.4334718883037567
#   y: 0.504686176776886
#   z: 0.009800545871257782
# }
# landmark {
#   x: 0.4360656142234802
#   y: 0.4806663393974304
#   z: 0.02244563400745392
# }
# landmark {
#   x: 0.43886202573776245
#   y: 0.4579108953475952
#   z: 0.03455431014299393
# }
# landmark {
#   x: 0.4694293141365051
#   y: 0.5723478198051453
#   z: 0.025750402361154556
# }
# landmark {
#   x: 0.48760005831718445
#   y: 0.5859255194664001
#   z: 0.03646951913833618
# }
# landmark {
#   x: 0.4349752366542816
#   y: 0.5631082653999329
#   z: 0.019837195053696632
# }
# landmark {
#   x: 0.48005202412605286
#   y: 0.5528435707092285
#   z: 0.03448435291647911
# }
# landmark {
#   x: 0.43001818656921387
#   y: 0.5731942057609558
#   z: 0.0011583884479478002
# }
# landmark {
#   x: 0.4331226050853729
#   y: 0.6023001670837402
#   z: -0.029184099286794662
# }
# landmark {
#   x: 0.49549925327301025
#   y: 0.5972172021865845
#   z: 0.044072166085243225
# }
# landmark {
#   x: 0.4824773073196411
#   y: 0.5915278792381287
#   z: 0.02638542652130127
# }
# landmark {
#   x: 0.47237515449523926
#   y: 0.5927577614784241
#   z: 0.016799477860331535
# }
# landmark {
#   x: 0.4568459987640381
#   y: 0.5894644856452942
#   z: 0.01253136433660984
# }
# landmark {
#   x: 0.4450454115867615
#   y: 0.5836667418479919
#   z: 0.010830847546458244
# }
# landmark {
#   x: 0.4360300302505493
#   y: 0.5765189528465271
#   z: 0.00949536357074976
# }
# landmark {
#   x: 0.41963252425193787
#   y: 0.5535000562667847
#   z: -0.003653312334790826
# }
# landmark {
#   x: 0.4942004084587097
#   y: 0.6209022998809814
#   z: 0.03556820750236511
# }
# landmark {
#   x: 0.48689112067222595
#   y: 0.5515331029891968
#   z: 0.03996049240231514
# }
# landmark {
#   x: 0.41640254855155945
#   y: 0.61209636926651
#   z: -0.040958937257528305
# }
# landmark {
#   x: 0.43512651324272156
#   y: 0.5914885401725769
#   z: -0.003947780933231115
# }
# landmark {
#   x: 0.5015736818313599
#   y: 0.5890457630157471
#   z: 0.10214582085609436
# }
# landmark {
#   x: 0.4295993149280548
#   y: 0.568404495716095
#   z: 0.009621093980967999
# }
# landmark {
#   x: 0.4391680955886841
#   y: 0.6144461035728455
#   z: -0.007541455794125795
# }
# landmark {
#   x: 0.47533372044563293
#   y: 0.5628666281700134
#   z: 0.03470597788691521
# }
# landmark {
#   x: 0.43320995569229126
#   y: 0.5965654850006104
#   z: -0.02457897923886776
# }
# landmark {
#   x: 0.49488118290901184
#   y: 0.6718648672103882
#   z: 0.08126336336135864
# }
# landmark {
#   x: 0.43475961685180664
#   y: 0.5593734979629517
#   z: 0.023103058338165283
# }
# landmark {
#   x: 0.42684465646743774
#   y: 0.5869072675704956
#   z: -0.031252410262823105
# }
# landmark {
#   x: 0.47461211681365967
#   y: 0.7127695679664612
#   z: 0.011502409353852272
# }
# landmark {
#   x: 0.4724428653717041
#   y: 0.7321310043334961
#   z: 0.02298586070537567
# }
# landmark {
#   x: 0.4998393952846527
#   y: 0.6327230334281921
#   z: 0.06458587944507599
# }
# landmark {
#   x: 0.48420268297195435
#   y: 0.7006913423538208
#   z: 0.027037177234888077
# }
# landmark {
#   x: 0.4978030323982239
#   y: 0.5552210807800293
#   z: 0.07131309807300568
# }
# landmark {
#   x: 0.440992146730423
#   y: 0.7418951988220215
#   z: -0.026470283046364784
# }
# landmark {
#   x: 0.4150867760181427
#   y: 0.6170498728752136
#   z: -0.032024312764406204
# }
# landmark {
#   x: 0.4421505630016327
#   y: 0.6018036603927612
#   z: -0.002800017362460494
# }
# landmark {
#   x: 0.49438416957855225
#   y: 0.5752987861633301
#   z: 0.052970390766859055
# }
# landmark {
#   x: 0.4625886082649231
#   y: 0.5669138431549072
#   z: 0.023024210706353188
# }
# landmark {
#   x: 0.4553372859954834
#   y: 0.5674360990524292
#   z: 0.020364731550216675
# }
# landmark {
#   x: 0.4410545527935028
#   y: 0.6759275197982788
#   z: -0.020281048491597176
# }
# landmark {
#   x: 0.4922303557395935
#   y: 0.6454431414604187
#   z: 0.030996086075901985
# }
# landmark {
#   x: 0.42456063628196716
#   y: 0.7598652839660645
#   z: -0.0293254591524601
# }
# landmark {
#   x: 0.44998884201049805
#   y: 0.7501678466796875
#   z: -0.006658053956925869
# }
# landmark {
#   x: 0.4605881869792938
#   y: 0.7431328892707825
#   z: 0.006339159328490496
# }
# landmark {
#   x: 0.44815924763679504
#   y: 0.5660653114318848
#   z: 0.01981891505420208
# }
# landmark {
#   x: 0.4415270984172821
#   y: 0.5632323622703552
#   z: 0.02090163342654705
# }
# landmark {
#   x: 0.4372347295284271
#   y: 0.5612033605575562
#   z: 0.022942237555980682
# }
# landmark {
#   x: 0.4923618733882904
#   y: 0.5516213178634644
#   z: 0.049610622227191925
# }
# landmark {
#   x: 0.44182902574539185
#   y: 0.5539453029632568
#   z: 0.02135750837624073
# }
# landmark {
#   x: 0.4488811492919922
#   y: 0.5529186129570007
#   z: 0.02075611986219883
# }
# landmark {
#   x: 0.4554394781589508
#   y: 0.5529007911682129
#   z: 0.021619312465190887
# }
# landmark {
#   x: 0.46225401759147644
#   y: 0.5548361539840698
#   z: 0.023930953815579414
# }
# landmark {
#   x: 0.4669795632362366
#   y: 0.5576724410057068
#   z: 0.026490159332752228
# }
# landmark {
#   x: 0.5015197992324829
#   y: 0.5573575496673584
#   z: 0.09612222760915756
# }
# landmark {
#   x: 0.4671818017959595
#   y: 0.5656713247299194
#   z: 0.02636663056910038
# }
# landmark {
#   x: 0.43803268671035767
#   y: 0.6418402791023254
#   z: -0.0207273680716753
# }
# landmark {
#   x: 0.4317779541015625
#   y: 0.6131629347801208
#   z: -0.02294587530195713
# }
# landmark {
#   x: 0.4226178824901581
#   y: 0.6337318420410156
#   z: -0.028233224526047707
# }
# landmark {
#   x: 0.4636988639831543
#   y: 0.7250728011131287
#   z: -0.001849064719863236
# }
# landmark {
#   x: 0.45285409688949585
#   y: 0.7338118553161621
#   z: -0.01411424670368433
# }
# landmark {
#   x: 0.4259156286716461
#   y: 0.746978223323822
#   z: -0.03731464594602585
# }
# landmark {
#   x: 0.48107126355171204
#   y: 0.7195050120353699
#   z: 0.04382788762450218
# }
# landmark {
#   x: 0.43687912821769714
#   y: 0.5566815137863159
#   z: 0.022562667727470398
# }
# landmark {
#   x: 0.4250611662864685
#   y: 0.5708415508270264
#   z: -0.010738430544734001
# }
# landmark {
#   x: 0.43843090534210205
#   y: 0.7556644678115845
#   z: -0.01982719451189041
# }
# landmark {
#   x: 0.4967063069343567
#   y: 0.6590011715888977
#   z: 0.055750392377376556
# }
# landmark {
#   x: 0.42587411403656006
#   y: 0.6660029888153076
#   z: -0.02733478508889675
# }
# landmark {
#   x: 0.4270210266113281
#   y: 0.6682731509208679
#   z: -0.029668616130948067
# }
# landmark {
#   x: 0.4280460476875305
#   y: 0.6727535724639893
#   z: -0.032726891338825226
# }
# landmark {
#   x: 0.4288555979728699
#   y: 0.6798151135444641
#   z: -0.03306262195110321
# }
# landmark {
#   x: 0.4307720959186554
#   y: 0.6956760287284851
#   z: -0.02968106046319008
# }
# landmark {
#   x: 0.4378538429737091
#   y: 0.6707331538200378
#   z: -0.018922952935099602
# }
# landmark {
#   x: 0.4404212236404419
#   y: 0.6698959469795227
#   z: -0.018610084429383278
# }
# landmark {
#   x: 0.44302427768707275
#   y: 0.6684291958808899
#   z: -0.017983661964535713
# }
# landmark {
#   x: 0.4512285888195038
#   y: 0.6628866791725159
#   z: -0.014119605533778667
# }
# landmark {
#   x: 0.48241645097732544
#   y: 0.6454551815986633
#   z: 0.012050575576722622
# }
# landmark {
#   x: 0.4246343970298767
#   y: 0.5625197291374207
#   z: -0.0005901088006794453
# }
# landmark {
#   x: 0.4287749230861664
#   y: 0.5466969609260559
#   z: 0.018410073593258858
# }
# landmark {
#   x: 0.4334486424922943
#   y: 0.5512891411781311
#   z: 0.02190345712006092
# }
# landmark {
#   x: 0.4360903203487396
#   y: 0.6697555780410767
#   z: -0.018557997420430183
# }
# landmark {
#   x: 0.4821309447288513
#   y: 0.6778536438941956
#   z: 0.01614970713853836
# }
# landmark {
#   x: 0.422079473733902
#   y: 0.5418197512626648
#   z: 0.007798695471137762
# }
# landmark {
#   x: 0.4353216290473938
#   y: 0.711467444896698
#   z: -0.02860724925994873
# }
# landmark {
#   x: 0.41965654492378235
#   y: 0.5624938607215881
#   z: -0.014643155969679356
# }
# landmark {
#   x: 0.4305698871612549
#   y: 0.589203417301178
#   z: -0.01484073605388403
# }
# landmark {
#   x: 0.42219218611717224
#   y: 0.7146978378295898
#   z: -0.03583407402038574
# }
# landmark {
#   x: 0.4549393653869629
#   y: 0.6945850253105164
#   z: -0.01368144154548645
# }
# landmark {
#   x: 0.44563212990760803
#   y: 0.6256005167961121
#   z: -0.007431734353303909
# }
# landmark {
#   x: 0.4458710253238678
#   y: 0.7050964832305908
#   z: -0.021483972668647766
# }
# landmark {
#   x: 0.46520403027534485
#   y: 0.6276423335075378
#   z: -0.002685380633920431
# }
# landmark {
#   x: 0.4536193013191223
#   y: 0.6388161778450012
#   z: -0.00885213352739811
# }
# landmark {
#   x: 0.47196513414382935
#   y: 0.649924635887146
#   z: -0.0008147505577653646
# }
# landmark {
#   x: 0.4250350594520569
#   y: 0.7317214012145996
#   z: -0.03848684951663017
# }
# landmark {
#   x: 0.43517184257507324
#   y: 0.5982144474983215
#   z: -0.01083934586495161
# }
# landmark {
#   x: 0.46179717779159546
#   y: 0.7074191570281982
#   z: -0.007938296534121037
# }
# landmark {
#   x: 0.4506889879703522
#   y: 0.7180198431015015
#   z: -0.017968211323022842
# }
# landmark {
#   x: 0.4622325301170349
#   y: 0.6806310415267944
#   z: -0.00783231295645237
# }
# landmark {
#   x: 0.4895399808883667
#   y: 0.6666879653930664
#   z: 0.027790497988462448
# }
# landmark {
#   x: 0.47221148014068604
#   y: 0.6867544054985046
#   z: 0.0008380432263948023
# }
# landmark {
#   x: 0.4921891987323761
#   y: 0.6822131276130676
#   z: 0.04466233775019646
# }
# landmark {
#   x: 0.4601500332355499
#   y: 0.6567794680595398
#   z: -0.008409373462200165
# }
# landmark {
#   x: 0.42988187074661255
#   y: 0.5810539126396179
#   z: -0.006931583862751722
# }
# landmark {
#   x: 0.43050503730773926
#   y: 0.6065042018890381
#   z: -0.03166903555393219
# }
# landmark {
#   x: 0.4353496730327606
#   y: 0.612773060798645
#   z: -0.024168075993657112
# }
# landmark {
#   x: 0.4274097979068756
#   y: 0.5965240597724915
#   z: -0.03634166717529297
# }
# landmark {
#   x: 0.43611860275268555
#   y: 0.5362719297409058
#   z: 0.018337225541472435
# }
# landmark {
#   x: 0.4498581886291504
#   y: 0.530024528503418
#   z: 0.018936004489660263
# }
# landmark {
#   x: 0.4612281918525696
#   y: 0.529528021812439
#   z: 0.02014026790857315
# }
# landmark {
#   x: 0.4706445634365082
#   y: 0.5330919623374939
#   z: 0.023886028677225113
# }
# landmark {
#   x: 0.47718364000320435
#   y: 0.5407965183258057
#   z: 0.02907336689531803
# }
# landmark {
#   x: 0.4809075593948364
#   y: 0.5661694407463074
#   z: 0.038243718445301056
# }
# landmark {
#   x: 0.5015920400619507
#   y: 0.607263445854187
#   z: 0.06972087919712067
# }
# landmark {
#   x: 0.4752206802368164
#   y: 0.5803869962692261
#   z: 0.02718408778309822
# }
# landmark {
#   x: 0.46711868047714233
#   y: 0.5816634893417358
#   z: 0.021057046949863434
# }
# landmark {
#   x: 0.45635539293289185
#   y: 0.5809451937675476
#   z: 0.01672595553100109
# }
# landmark {
#   x: 0.4456462860107422
#   y: 0.5773654580116272
#   z: 0.014684035442769527
# }
# landmark {
#   x: 0.4372018575668335
#   y: 0.5719426274299622
#   z: 0.015133431181311607
# }
# landmark {
#   x: 0.43155062198638916
#   y: 0.5664974451065063
#   z: 0.01491086371243
# }
# landmark {
#   x: 0.49966147541999817
#   y: 0.6169627904891968
#   z: 0.10081718116998672
# }
# landmark {
#   x: 0.43455082178115845
#   y: 0.6172069311141968
#   z: -0.020882684737443924
# }
# landmark {
#   x: 0.42535853385925293
#   y: 0.5784818530082703
#   z: -0.019849559292197227
# }
# landmark {
#   x: 0.42503851652145386
#   y: 0.6042928099632263
#   z: -0.03867689147591591
# }
# landmark {
#   x: 0.4198310971260071
#   y: 0.6116483807563782
#   z: -0.03733018785715103
# }
# landmark {
#   x: 0.4245764911174774
#   y: 0.6076152920722961
#   z: -0.035219188779592514
# }
# landmark {
#   x: 0.43178650736808777
#   y: 0.6215319633483887
#   z: -0.019386863335967064
# }
# landmark {
#   x: 0.41875776648521423
#   y: 0.6118988394737244
#   z: -0.03976006805896759
# }
# landmark {
#   x: 0.4174400269985199
#   y: 0.6165890097618103
#   z: -0.03155669569969177
# }
# landmark {
#   x: 0.4318292737007141
#   y: 0.5585017800331116
#   z: 0.021421359851956367
# }
# landmark {
#   x: 0.4272254407405853
#   y: 0.5587545037269592
#   z: 0.015538294799625874
# }
# landmark {
#   x: 0.4249398112297058
#   y: 0.5579829812049866
#   z: 0.009153272025287151
# }
# landmark {
#   x: 0.4699755012989044
#   y: 0.559955894947052
#   z: 0.029386762529611588
# }
# landmark {
#   x: 0.47505682706832886
#   y: 0.5541675090789795
#   z: 0.03052155114710331
# }

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.42446589,  0.59984004, -0.71082056, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.42446589,  0.59984004, -0.71082056, ...,  0.        ,
#         0.        ,  0.        ])

# %% [markdown]
# # Setup folders for collection

# %%
import os
import numpy as np
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('C:/Users/USER/Desktop/GIRLS/da') 

# Actions that we try to detect
actions = np.array(['angry','worry','shock','dimanche', 'vendredi', 'jeudi','mardi','mercredi','lundi','samedi','blue','black','green','rose','orange'])

# Thirty videos worth of data
no_sequences = 10

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 0

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
print(results)
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
import cv2
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(start_folder, start_folder+no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints,allow_pickle=True)
                

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
  cap.release()
    cv2.destroyAllWindows()
# Out:
#   Cell In[29], line 2
#     cv2.destroyAllWindows()
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # preprocessing

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'angry': 0,
#  'worry': 1,
#  'shock': 2,
#  'dimanche': 3,
#  'vendredi': 4,
#  'jeudi': 5,
#  'mardi': 6,
#  'mercredi': 7,
#  'lundi': 8,
#  'samedi': 9,
#  'blue': 10,
#  'black': 11,
#  'green': 12,
#  'rose': 13,
#  'orange': 14}

# %%
sequences, labels = [], []
for action in actions:
    for sequence  in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (150, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (150,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (150, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)
y_test.shape
# Out:
# (8, 15)

# %%
#LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %% [markdown]
# model = Sequential()
# model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
# model.add(LSTM(128, return_sequences=True, activation='relu'))
# model.add(LSTM(64, return_sequences=False, activation='relu'))
# model.add(Dense(64, activation='relu'))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(actions.shape[0], activation='softmax'))
# model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# model.summary()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed
from tensorflow.keras.callbacks import TensorBoard
from sklearn.model_selection import train_test_split
import numpy as np

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# Define the model architecture
model = Sequential()
model.add(LSTM(128, return_sequences=True, activation='tanh', input_shape=(30, 1662)))
model.add(Dropout(0.3))
model.add(LSTM(64, return_sequences=True, activation='tanh'))
model.add(Dropout(0.2))
model.add(LSTM(32, return_sequences=False, activation='tanh'))
model.add(Dropout(0.1))
model.add(Dense(actions.shape[0], activation='softmax'))

# Compile the model
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# Define the TensorBoard callback
tb_callback = TensorBoard(log_dir='./logs', histogram_freq=1)

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=[tb_callback])

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 10s 581ms/step - loss: 2.7475 - categorical_accuracy: 0.0915 - val_loss: 2.7807 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 5/5 [==============================] - 1s 243ms/step - loss: 2.7116 - categorical_accuracy: 0.0845 - val_loss: 2.7557 - val_categorical_accuracy: 0.0000e+00
# Epoch 3/100
# 5/5 [==============================] - 1s 261ms/step - loss: 2.6488 - categorical_accuracy: 0.1479 - val_loss: 2.7228 - val_categorical_accuracy: 0.1250
# Epoch 4/100
# 5/5 [==============================] - 1s 270ms/step - loss: 2.6407 - categorical_accuracy: 0.1549 - val_loss: 2.5870 - val_categorical_accuracy: 0.0000e+00
# Epoch 5/100
# 5/5 [==============================] - 2s 370ms/step - loss: 2.5949 - categorical_accuracy: 0.1549 - val_loss: 2.5208 - val_categorical_accuracy: 0.1250
# Epoch 6/100
# 5/5 [==============================] - 1s 262ms/step - loss: 2.5446 - categorical_accuracy: 0.1479 - val_loss: 2.6263 - val_categorical_accuracy: 0.1250
# Epoch 7/100
# 5/5 [==============================] - 1s 230ms/step - loss: 2.4889 - categorical_accuracy: 0.1901 - val_loss: 2.3615 - val_categorical_accuracy: 0.3750
# Epoch 8/100
# 5/5 [==============================] - 1s 252ms/step - loss: 2.3957 - categorical_accuracy: 0.2324 - val_loss: 2.3111 - val_categorical_accuracy: 0.3750
# Epoch 9/100
# 5/5 [==============================] - 1s 229ms/step - loss: 2.4251 - categorical_accuracy: 0.1408 - val_loss: 2.5269 - val_categorical_accuracy: 0.1250
# Epoch 10/100
# 5/5 [==============================] - 1s 216ms/step - loss: 2.2764 - categorical_accuracy: 0.2535 - val_loss: 2.5688 - val_categorical_accuracy: 0.0000e+00
# Epoch 11/100
# 5/5 [==============================] - 1s 224ms/step - loss: 2.1958 - categorical_accuracy: 0.2465 - val_loss: 2.3727 - val_categorical_accuracy: 0.1250
# Epoch 12/100
# 5/5 [==============================] - 1s 218ms/step - loss: 2.1272 - categorical_accuracy: 0.2676 - val_loss: 2.5239 - val_categorical_accuracy: 0.1250
# Epoch 13/100
# 5/5 [==============================] - 1s 217ms/step - loss: 2.1182 - categorical_accuracy: 0.3310 - val_loss: 2.6254 - val_categorical_accuracy: 0.1250
# Epoch 14/100
# 5/5 [==============================] - 1s 227ms/step - loss: 2.0611 - categorical_accuracy: 0.3028 - val_loss: 2.3714 - val_categorical_accuracy: 0.0000e+00
# Epoch 15/100
# 5/5 [==============================] - 1s 248ms/step - loss: 1.9295 - categorical_accuracy: 0.3873 - val_loss: 2.0326 - val_categorical_accuracy: 0.5000
# Epoch 16/100
# 5/5 [==============================] - 1s 254ms/step - loss: 1.8470 - categorical_accuracy: 0.4366 - val_loss: 2.2274 - val_categorical_accuracy: 0.3750
# Epoch 17/100
# 5/5 [==============================] - 1s 276ms/step - loss: 1.8433 - categorical_accuracy: 0.3873 - val_loss: 2.2361 - val_categorical_accuracy: 0.2500
# Epoch 18/100
# 5/5 [==============================] - 1s 287ms/step - loss: 1.8352 - categorical_accuracy: 0.3944 - val_loss: 2.3428 - val_categorical_accuracy: 0.1250
# Epoch 19/100
# 5/5 [==============================] - 1s 310ms/step - loss: 1.7815 - categorical_accuracy: 0.3662 - val_loss: 1.8350 - val_categorical_accuracy: 0.3750
# Epoch 20/100
# 5/5 [==============================] - 1s 295ms/step - loss: 1.7483 - categorical_accuracy: 0.3944 - val_loss: 1.8948 - val_categorical_accuracy: 0.5000
# Epoch 21/100
# 5/5 [==============================] - 1s 244ms/step - loss: 1.6964 - categorical_accuracy: 0.4859 - val_loss: 2.0021 - val_categorical_accuracy: 0.5000
# Epoch 22/100
# 5/5 [==============================] - 1s 259ms/step - loss: 1.6501 - categorical_accuracy: 0.4296 - val_loss: 1.7219 - val_categorical_accuracy: 0.5000
# Epoch 23/100
# 5/5 [==============================] - 1s 244ms/step - loss: 1.4508 - categorical_accuracy: 0.5282 - val_loss: 1.6651 - val_categorical_accuracy: 0.5000
# Epoch 24/100
# 5/5 [==============================] - 1s 223ms/step - loss: 1.5556 - categorical_accuracy: 0.4930 - val_loss: 1.6904 - val_categorical_accuracy: 0.3750
# Epoch 25/100
# 5/5 [==============================] - 1s 227ms/step - loss: 1.4883 - categorical_accuracy: 0.4789 - val_loss: 1.7041 - val_categorical_accuracy: 0.5000
# Epoch 26/100
# 5/5 [==============================] - 1s 227ms/step - loss: 1.4342 - categorical_accuracy: 0.5000 - val_loss: 1.9666 - val_categorical_accuracy: 0.3750
# Epoch 27/100
# 5/5 [==============================] - 1s 261ms/step - loss: 1.5302 - categorical_accuracy: 0.4507 - val_loss: 1.4807 - val_categorical_accuracy: 0.5000
# Epoch 28/100
# 5/5 [==============================] - 1s 237ms/step - loss: 1.5113 - categorical_accuracy: 0.5000 - val_loss: 1.4941 - val_categorical_accuracy: 0.6250
# Epoch 29/100
# 5/5 [==============================] - 1s 231ms/step - loss: 1.3553 - categorical_accuracy: 0.5493 - val_loss: 1.4454 - val_categorical_accuracy: 0.5000
# Epoch 30/100
# 5/5 [==============================] - 1s 244ms/step - loss: 1.3404 - categorical_accuracy: 0.5493 - val_loss: 1.3546 - val_categorical_accuracy: 0.5000
# Epoch 31/100
# 5/5 [==============================] - 1s 277ms/step - loss: 1.2726 - categorical_accuracy: 0.5986 - val_loss: 1.8281 - val_categorical_accuracy: 0.1250
# Epoch 32/100
# 5/5 [==============================] - 1s 311ms/step - loss: 1.2496 - categorical_accuracy: 0.5704 - val_loss: 1.5997 - val_categorical_accuracy: 0.5000
# Epoch 33/100
# 5/5 [==============================] - 1s 305ms/step - loss: 1.2072 - categorical_accuracy: 0.6549 - val_loss: 1.7441 - val_categorical_accuracy: 0.6250
# Epoch 34/100
# 5/5 [==============================] - 1s 276ms/step - loss: 1.1933 - categorical_accuracy: 0.5845 - val_loss: 1.5597 - val_categorical_accuracy: 0.5000
# Epoch 35/100
# 5/5 [==============================] - 1s 265ms/step - loss: 1.2424 - categorical_accuracy: 0.5845 - val_loss: 1.5711 - val_categorical_accuracy: 0.6250
# Epoch 36/100
# 5/5 [==============================] - 1s 250ms/step - loss: 1.5326 - categorical_accuracy: 0.5000 - val_loss: 1.6395 - val_categorical_accuracy: 0.2500
# Epoch 37/100
# 5/5 [==============================] - 1s 263ms/step - loss: 1.5122 - categorical_accuracy: 0.4648 - val_loss: 2.1045 - val_categorical_accuracy: 0.5000
# Epoch 38/100
# 5/5 [==============================] - 1s 265ms/step - loss: 1.4072 - categorical_accuracy: 0.5423 - val_loss: 1.5265 - val_categorical_accuracy: 0.6250
# Epoch 39/100
# 5/5 [==============================] - 1s 253ms/step - loss: 1.2675 - categorical_accuracy: 0.5704 - val_loss: 1.7358 - val_categorical_accuracy: 0.6250
# Epoch 40/100
# 5/5 [==============================] - 1s 229ms/step - loss: 1.2010 - categorical_accuracy: 0.5986 - val_loss: 1.7844 - val_categorical_accuracy: 0.2500
# Epoch 41/100
# 5/5 [==============================] - 1s 228ms/step - loss: 1.2247 - categorical_accuracy: 0.5915 - val_loss: 2.3558 - val_categorical_accuracy: 0.5000
# Epoch 42/100
# 5/5 [==============================] - 1s 247ms/step - loss: 1.2296 - categorical_accuracy: 0.5634 - val_loss: 1.4567 - val_categorical_accuracy: 0.5000
# Epoch 43/100
# 5/5 [==============================] - 1s 256ms/step - loss: 1.1864 - categorical_accuracy: 0.6127 - val_loss: 1.7159 - val_categorical_accuracy: 0.5000
# Epoch 44/100
# 5/5 [==============================] - 1s 259ms/step - loss: 1.1756 - categorical_accuracy: 0.5915 - val_loss: 1.4393 - val_categorical_accuracy: 0.5000
# Epoch 45/100
# 5/5 [==============================] - 1s 261ms/step - loss: 1.0435 - categorical_accuracy: 0.6972 - val_loss: 1.3780 - val_categorical_accuracy: 0.6250
# Epoch 46/100
# 5/5 [==============================] - 1s 237ms/step - loss: 1.0344 - categorical_accuracy: 0.6831 - val_loss: 1.3070 - val_categorical_accuracy: 0.5000
# Epoch 47/100
# 5/5 [==============================] - 1s 258ms/step - loss: 0.9214 - categorical_accuracy: 0.7183 - val_loss: 1.6592 - val_categorical_accuracy: 0.3750
# Epoch 48/100
# 5/5 [==============================] - 1s 254ms/step - loss: 0.9979 - categorical_accuracy: 0.6620 - val_loss: 1.3742 - val_categorical_accuracy: 0.6250
# Epoch 49/100
# 5/5 [==============================] - 1s 235ms/step - loss: 0.9595 - categorical_accuracy: 0.6972 - val_loss: 1.2339 - val_categorical_accuracy: 0.6250
# Epoch 50/100
# 5/5 [==============================] - 1s 244ms/step - loss: 0.8369 - categorical_accuracy: 0.7324 - val_loss: 1.9733 - val_categorical_accuracy: 0.3750
# Epoch 51/100
# 5/5 [==============================] - 1s 222ms/step - loss: 0.9332 - categorical_accuracy: 0.7042 - val_loss: 1.4181 - val_categorical_accuracy: 0.5000
# Epoch 52/100
# 5/5 [==============================] - 1s 208ms/step - loss: 0.8669 - categorical_accuracy: 0.7465 - val_loss: 1.0298 - val_categorical_accuracy: 0.6250
# Epoch 53/100
# 5/5 [==============================] - 1s 213ms/step - loss: 0.8203 - categorical_accuracy: 0.7465 - val_loss: 1.9074 - val_categorical_accuracy: 0.3750
# Epoch 54/100
# 5/5 [==============================] - 1s 211ms/step - loss: 0.8862 - categorical_accuracy: 0.7324 - val_loss: 1.2819 - val_categorical_accuracy: 0.6250
# Epoch 55/100
# 5/5 [==============================] - 1s 210ms/step - loss: 1.3815 - categorical_accuracy: 0.5282 - val_loss: 2.1374 - val_categorical_accuracy: 0.2500
# Epoch 56/100
# 5/5 [==============================] - 1s 212ms/step - loss: 1.2429 - categorical_accuracy: 0.5775 - val_loss: 1.4348 - val_categorical_accuracy: 0.2500
# Epoch 57/100
# 5/5 [==============================] - 1s 207ms/step - loss: 0.9957 - categorical_accuracy: 0.6549 - val_loss: 1.5485 - val_categorical_accuracy: 0.6250
# Epoch 58/100
# 5/5 [==============================] - 1s 228ms/step - loss: 1.0528 - categorical_accuracy: 0.6408 - val_loss: 1.4948 - val_categorical_accuracy: 0.2500
# Epoch 59/100
# 5/5 [==============================] - 1s 252ms/step - loss: 0.9651 - categorical_accuracy: 0.6901 - val_loss: 1.4097 - val_categorical_accuracy: 0.2500
# Epoch 60/100
# 5/5 [==============================] - 1s 234ms/step - loss: 1.0306 - categorical_accuracy: 0.6408 - val_loss: 1.6957 - val_categorical_accuracy: 0.2500
# Epoch 61/100
# 5/5 [==============================] - 1s 229ms/step - loss: 1.1656 - categorical_accuracy: 0.5563 - val_loss: 1.4080 - val_categorical_accuracy: 0.2500
# Epoch 62/100
# 5/5 [==============================] - 1s 226ms/step - loss: 1.0823 - categorical_accuracy: 0.5634 - val_loss: 1.2234 - val_categorical_accuracy: 0.5000
# Epoch 63/100
# 5/5 [==============================] - 1s 213ms/step - loss: 1.0508 - categorical_accuracy: 0.6197 - val_loss: 1.1059 - val_categorical_accuracy: 0.3750
# Epoch 64/100
# 5/5 [==============================] - 1s 219ms/step - loss: 0.9837 - categorical_accuracy: 0.6690 - val_loss: 1.6510 - val_categorical_accuracy: 0.2500
# Epoch 65/100
# 5/5 [==============================] - 1s 207ms/step - loss: 0.9730 - categorical_accuracy: 0.6690 - val_loss: 1.0988 - val_categorical_accuracy: 0.6250
# Epoch 66/100
# 5/5 [==============================] - 1s 218ms/step - loss: 0.8644 - categorical_accuracy: 0.6901 - val_loss: 1.1997 - val_categorical_accuracy: 0.6250
# Epoch 67/100
# 5/5 [==============================] - 1s 233ms/step - loss: 0.8127 - categorical_accuracy: 0.7394 - val_loss: 0.9991 - val_categorical_accuracy: 0.6250
# Epoch 68/100
# 5/5 [==============================] - 1s 218ms/step - loss: 0.7898 - categorical_accuracy: 0.7254 - val_loss: 1.1877 - val_categorical_accuracy: 0.6250
# Epoch 69/100
# 5/5 [==============================] - 1s 227ms/step - loss: 0.7604 - categorical_accuracy: 0.7606 - val_loss: 1.0495 - val_categorical_accuracy: 0.7500
# Epoch 70/100
# 5/5 [==============================] - 1s 238ms/step - loss: 0.7310 - categorical_accuracy: 0.7817 - val_loss: 1.2411 - val_categorical_accuracy: 0.7500
# Epoch 71/100
# 5/5 [==============================] - 1s 224ms/step - loss: 0.7964 - categorical_accuracy: 0.7394 - val_loss: 1.2328 - val_categorical_accuracy: 0.7500
# Epoch 72/100
# 5/5 [==============================] - 1s 213ms/step - loss: 0.9166 - categorical_accuracy: 0.6831 - val_loss: 1.8821 - val_categorical_accuracy: 0.2500
# Epoch 73/100
# 5/5 [==============================] - 1s 207ms/step - loss: 0.7689 - categorical_accuracy: 0.7535 - val_loss: 0.8722 - val_categorical_accuracy: 0.7500
# Epoch 74/100
# 5/5 [==============================] - 1s 240ms/step - loss: 0.7445 - categorical_accuracy: 0.7535 - val_loss: 1.6191 - val_categorical_accuracy: 0.3750
# Epoch 75/100
# 5/5 [==============================] - 1s 239ms/step - loss: 1.1646 - categorical_accuracy: 0.5845 - val_loss: 1.6349 - val_categorical_accuracy: 0.5000
# Epoch 76/100
# 5/5 [==============================] - 1s 244ms/step - loss: 0.9147 - categorical_accuracy: 0.6549 - val_loss: 2.2271 - val_categorical_accuracy: 0.5000
# Epoch 77/100
# 5/5 [==============================] - 1s 227ms/step - loss: 1.0127 - categorical_accuracy: 0.6549 - val_loss: 1.3186 - val_categorical_accuracy: 0.5000
# Epoch 78/100
# 5/5 [==============================] - 1s 217ms/step - loss: 1.0110 - categorical_accuracy: 0.6408 - val_loss: 1.0234 - val_categorical_accuracy: 0.5000
# Epoch 79/100
# 5/5 [==============================] - 1s 220ms/step - loss: 0.8696 - categorical_accuracy: 0.7113 - val_loss: 1.1158 - val_categorical_accuracy: 0.6250
# Epoch 80/100
# 5/5 [==============================] - 1s 219ms/step - loss: 0.7998 - categorical_accuracy: 0.7465 - val_loss: 1.1923 - val_categorical_accuracy: 0.6250
# Epoch 81/100
# 5/5 [==============================] - 1s 218ms/step - loss: 0.8231 - categorical_accuracy: 0.6972 - val_loss: 1.2093 - val_categorical_accuracy: 0.6250
# Epoch 82/100
# 5/5 [==============================] - 1s 246ms/step - loss: 0.7524 - categorical_accuracy: 0.7394 - val_loss: 1.1141 - val_categorical_accuracy: 0.6250
# Epoch 83/100
# 5/5 [==============================] - 1s 241ms/step - loss: 0.7980 - categorical_accuracy: 0.7113 - val_loss: 1.6513 - val_categorical_accuracy: 0.2500
# Epoch 84/100
# 5/5 [==============================] - 1s 220ms/step - loss: 0.8505 - categorical_accuracy: 0.6972 - val_loss: 1.1430 - val_categorical_accuracy: 0.6250
# Epoch 85/100
# 5/5 [==============================] - 1s 213ms/step - loss: 0.8794 - categorical_accuracy: 0.6901 - val_loss: 1.5115 - val_categorical_accuracy: 0.3750
# Epoch 86/100
# 5/5 [==============================] - 1s 211ms/step - loss: 0.8658 - categorical_accuracy: 0.6901 - val_loss: 1.4171 - val_categorical_accuracy: 0.2500
# Epoch 87/100
# 5/5 [==============================] - 1s 216ms/step - loss: 0.7040 - categorical_accuracy: 0.7817 - val_loss: 1.2896 - val_categorical_accuracy: 0.7500
# Epoch 88/100
# 5/5 [==============================] - 1s 211ms/step - loss: 0.7769 - categorical_accuracy: 0.7535 - val_loss: 1.6510 - val_categorical_accuracy: 0.2500
# Epoch 89/100
# 5/5 [==============================] - 1s 234ms/step - loss: 0.7330 - categorical_accuracy: 0.7676 - val_loss: 0.9612 - val_categorical_accuracy: 0.5000
# Epoch 90/100
# 5/5 [==============================] - 1s 231ms/step - loss: 0.7571 - categorical_accuracy: 0.7465 - val_loss: 2.1850 - val_categorical_accuracy: 0.3750
# Epoch 91/100
# 5/5 [==============================] - 1s 242ms/step - loss: 0.8983 - categorical_accuracy: 0.6408 - val_loss: 0.8671 - val_categorical_accuracy: 0.6250
# Epoch 92/100
# 5/5 [==============================] - 1s 227ms/step - loss: 0.7386 - categorical_accuracy: 0.7324 - val_loss: 1.4178 - val_categorical_accuracy: 0.2500
# Epoch 93/100
# 5/5 [==============================] - 1s 213ms/step - loss: 0.7399 - categorical_accuracy: 0.7606 - val_loss: 1.2447 - val_categorical_accuracy: 0.5000
# Epoch 94/100
# 5/5 [==============================] - 1s 216ms/step - loss: 0.6773 - categorical_accuracy: 0.7606 - val_loss: 1.3755 - val_categorical_accuracy: 0.6250
# Epoch 95/100
# 5/5 [==============================] - 1s 221ms/step - loss: 0.5968 - categorical_accuracy: 0.8239 - val_loss: 0.9613 - val_categorical_accuracy: 0.7500
# Epoch 96/100
# 5/5 [==============================] - 1s 218ms/step - loss: 0.5606 - categorical_accuracy: 0.8803 - val_loss: 1.1338 - val_categorical_accuracy: 0.6250
# Epoch 97/100
# 5/5 [==============================] - 1s 233ms/step - loss: 0.5584 - categorical_accuracy: 0.8380 - val_loss: 0.8822 - val_categorical_accuracy: 0.6250
# Epoch 98/100
# 5/5 [==============================] - 1s 263ms/step - loss: 0.5834 - categorical_accuracy: 0.8099 - val_loss: 1.0546 - val_categorical_accuracy: 0.3750
# Epoch 99/100
# 5/5 [==============================] - 1s 237ms/step - loss: 0.5317 - categorical_accuracy: 0.8310 - val_loss: 0.9613 - val_categorical_accuracy: 0.5000
# Epoch 100/100
# 5/5 [==============================] - 1s 220ms/step - loss: 0.5348 - categorical_accuracy: 0.8662 - val_loss: 0.9711 - val_categorical_accuracy: 0.5000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.9711 - categorical_accuracy: 0.5000
# Test loss: 0.9710913896560669
# Test accuracy: 0.5

# %%
#model.save('C:\\Users\\USER\\my_model.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 model.save('C:\\Users\\USER\\my_model.h5')
#
# NameError: name 'model' is not defined

# %%
from tensorflow.keras.models import load_model
loaded_model = load_model('my_model.h5')

# %%
res = loaded_model.predict(X_test)
actions[np.argmax(res[4])]
# Out:
# 1/1 [==============================] - 2s 2s/step
# 'vendredi'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'vendredi'

# %%
loaded_model.load_weights('C:\\Users\\USER\\my_model.h5')

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
yhat =loaded_model.predict(X_test)
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# array([[[7, 0],
#         [0, 1]],
#
#        [[6, 0],
#         [0, 2]],
#
#        [[7, 0],
#         [0, 1]],
#
#        [[7, 0],
#         [0, 1]],
#
#        [[7, 0],
#         [0, 1]],
#
#        [[7, 1],
#         [0, 0]],
#
#        [[7, 0],
#         [0, 1]],
#
#        [[7, 0],
#         [1, 0]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.875

# %%
res = loaded_model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 42ms/step

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)] * 5
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)] * 5
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        color = colors[num % len(colors)]
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob.mean()*100), 90+num*40), color, -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))

# %%
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = loaded_model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 50ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 49ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# vendredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# mercredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# mercredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# mardi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# mercredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# mercredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# mercredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# mercredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# mercredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# mercredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# mercredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# mercredi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# black
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# samedi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# samedi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# angry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# jeudi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# jeudi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# jeudi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# jeudi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# jeudi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# jeudi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# jeudi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# jeudi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# green
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# blue
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# lundi
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# rose
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# orange
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
